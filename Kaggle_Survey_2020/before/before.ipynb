# %% [markdown]
# # The future of ML (Americans vs Indians)
#
# Since I started Kaggle competitions, I had a cute question. I called it beginner's curiosity.
#
# **"Have you ever thought which countries have the biggest impact on Kaggle competition?"**
#
# As everybody knows, the USA is an obvious IT powerhouse with Silicon Valley. It has the largest number of Kaggle Grandmaster Champions. There is no doubt that the USA has the most influence on Kaggle competitions.
#
# You can also see a lot of Indians on the participants list of it. India, known as the rising IT powerhouse, it actually interested in the Kaggle competitions. It can be confirmed easily by checking a percentage of respondents to the 《2020 Kaggle Machine Learning & Data Science Survey》. The response rate for Indians is the highest about 29.2%(5,850 people). It is higher than the second-ranked country, and I will explain the details below.
#
# Plus, a few years ago, every country emphasize the importance of Machine Learning. Because It can be used lots of fields in the world. I also wondered the future of ML, so I decided to look into the future of Machine Learning through responses from two leader countires.
#
# **"Do you know the future of Machine Learning?"**
#
# To sum up, I will compare the responses of American and Indian in the order below.
#
#
# ## Contents
# 1. Responses Rate by Country
# 2. Percentage by age & gender
# 3. Level of Education
# 4. Development Environment
# 5. Basic of Machine Learning
# 6. CV vs NLP
# 7. Machine Learning in the business

# %% [markdown]
# ## Library & Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.dpi'] = 200
import plotly.express as px
import seaborn as sns

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import zipfile
DATA_IN_PATH = './data/'
file_list = ['kaggle-survey-2020.zip']

for file in file_list:
    zipRef = zipfile.ZipFile(DATA_IN_PATH + file, 'r')
    zipRef.extractall(DATA_IN_PATH)
    zipRef.close()

# %%
survey = pd.read_csv('./data/kaggle_survey_2020_responses.csv')
question = survey.iloc[0,:].T
full_data = survey.iloc[1:,:]

full_data[full_data.columns[3]].replace({'United States of America':'USA',
                                         'United Kingdom of Great Britain and Northern Ireland':'UK'}, inplace=True)
# Out:
# C:\Users\naeun\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning:
#
# Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#
# C:\Users\naeun\anaconda3\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
question.head()
# Out:
# Time from Start to Finish (seconds)                                Duration (in seconds)
# Q1                                                           What is your age (# years)?
# Q2                                                What is your gender? - Selected Choice
# Q3                                             In which country do you currently reside?
# Q4                                     What is the highest level of formal education ...
# Name: 0, dtype: object

# %%
full_data.head(30)
# Out:
#    Time from Start to Finish (seconds)     Q1     Q2            Q3  \
# 1                                 1838  35-39    Man      Colombia
# 2                               289287  30-34    Man           USA
# 3                                  860  35-39    Man     Argentina
# 4                                  507  30-34    Man           USA
# 5                                   78  30-34    Man         Japan
# 6                                  401  30-34    Man         India
# 7                                  748  22-24    Man        Brazil
# 8                               171196  25-29  Woman         China
# 9                                  762  35-39    Man       Germany
# 10                                 150  22-24    Man         China
# 11                                7469  18-21    Man         India
# 12                                 742  35-39    Man           USA
# 13                                 535  22-24    Man     Indonesia
# 14                                 378  30-34    Man        Canada
# 15                                 623  30-34    Man   Switzerland
# 16                                 413  18-21  Woman         India
# 17                                 397  25-29  Woman         Other
# 18                                 437  22-24    Man     Singapore
# 19                                 192  22-24    Man         India
# 20                                 267  18-21    Man         India
# 21                                3313  22-24  Woman         India
# 22                                 874  30-34    Man        Russia
# 23                                 815  55-59  Woman        Canada
# 24                                 694  35-39    Man  South Africa
# 25                                 571  50-54    Man           USA
# 26                                 723  25-29  Woman           USA
# 27                                 433  18-21    Man         India
# 28                                 273  18-21    Man         Egypt
# 29                                 545  30-34    Man   Netherlands
# 30                                1009  25-29    Man        Russia
#
#                                                    Q4  \
# 1                                     Doctoral degree
# 2                                     Master’s degree
# 3                                   Bachelor’s degree
# 4                                     Master’s degree
# 5                                     Master’s degree
# 6                                   Bachelor’s degree
# 7                                   Bachelor’s degree
# 8                                     Master’s degree
# 9                                     Doctoral degree
# 10               No formal education past high school
# 11                                  Bachelor’s degree
# 12                                    Doctoral degree
# 13                                  Bachelor’s degree
# 14                                  Bachelor’s degree
# 15                                  Bachelor’s degree
# 16                                  Bachelor’s degree
# 17                                  Bachelor’s degree
# 18                                  Bachelor’s degree
# 19                                  Bachelor’s degree
# 20                                  Bachelor’s degree
# 21                                    Doctoral degree
# 22                                  Bachelor’s degree
# 23                                    Master’s degree
# 24  Some college/university study without earning ...
# 25                                    Master’s degree
# 26                                    Master’s degree
# 27                                  Bachelor’s degree
# 28                                  Bachelor’s degree
# 29                                  Bachelor’s degree
# 30                                  Bachelor’s degree
#
#                            Q5           Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  ...  \
# 1                     Student   5-10 years    Python         R       SQL  ...
# 2               Data Engineer   5-10 years    Python         R       SQL  ...
# 3           Software Engineer  10-20 years       NaN       NaN       NaN  ...
# 4              Data Scientist   5-10 years    Python       NaN       SQL  ...
# 5           Software Engineer    3-5 years    Python       NaN       NaN  ...
# 6                Data Analyst    < 1 years    Python         R       NaN  ...
# 7                     Student    3-5 years    Python         R       NaN  ...
# 8                     Student    < 1 years       NaN         R       NaN  ...
# 9              Data Scientist   5-10 years    Python       NaN       SQL  ...
# 10                    Student    < 1 years    Python       NaN       SQL  ...
# 11                    Student    1-2 years    Python         R       SQL  ...
# 12         Research Scientist    1-2 years       NaN         R       NaN  ...
# 13                    Student    < 1 years    Python         R       SQL  ...
# 14              Data Engineer    < 1 years    Python       NaN       SQL  ...
# 15                      Other    < 1 years    Python         R       NaN  ...
# 16                    Student    1-2 years       NaN         R       SQL  ...
# 17     Currently not employed    3-5 years       NaN       NaN       SQL  ...
# 18                    Student    3-5 years    Python       NaN       NaN  ...
# 19                    Student    1-2 years    Python       NaN       SQL  ...
# 20                    Student    1-2 years    Python       NaN       NaN  ...
# 21               Statistician    3-5 years       NaN         R       SQL  ...
# 22             Data Scientist    < 1 years    Python       NaN       SQL  ...
# 23    Product/Project Manager    1-2 years    Python       NaN       NaN  ...
# 24               Data Analyst    < 1 years    Python       NaN       SQL  ...
# 25          Software Engineer    20+ years    Python       NaN       NaN  ...
# 26                    Student    1-2 years    Python         R       NaN  ...
# 27                    Student    3-5 years    Python       NaN       NaN  ...
# 28                    Student    1-2 years    Python       NaN       NaN  ...
# 29          Software Engineer  10-20 years    Python       NaN       NaN  ...
# 30  Machine Learning Engineer    3-5 years    Python       NaN       NaN  ...
#
#           Q35_B_Part_2 Q35_B_Part_3 Q35_B_Part_4   Q35_B_Part_5 Q35_B_Part_6  \
# 1                  NaN          NaN          NaN   TensorBoard           NaN
# 2                  NaN          NaN          NaN            NaN          NaN
# 3                  NaN          NaN          NaN            NaN          NaN
# 4                  NaN          NaN          NaN            NaN          NaN
# 5                  NaN          NaN          NaN            NaN          NaN
# 6                  NaN          NaN          NaN            NaN          NaN
# 7                  NaN          NaN          NaN            NaN          NaN
# 8                  NaN          NaN          NaN            NaN          NaN
# 9                  NaN          NaN          NaN            NaN          NaN
# 10                 NaN          NaN          NaN            NaN          NaN
# 11                 NaN          NaN          NaN            NaN          NaN
# 12                 NaN          NaN          NaN            NaN          NaN
# 13                 NaN          NaN          NaN            NaN          NaN
# 14                 NaN          NaN          NaN            NaN          NaN
# 15                 NaN          NaN          NaN            NaN          NaN
# 16                 NaN          NaN          NaN            NaN          NaN
# 17                 NaN          NaN          NaN   TensorBoard           NaN
# 18                 NaN          NaN          NaN   TensorBoard           NaN
# 19                 NaN          NaN          NaN            NaN          NaN
# 20                 NaN          NaN          NaN            NaN          NaN
# 21   Weights & Biases           NaN          NaN            NaN          NaN
# 22                 NaN          NaN          NaN            NaN          NaN
# 23                 NaN          NaN          NaN            NaN          NaN
# 24                 NaN          NaN          NaN            NaN          NaN
# 25                 NaN          NaN          NaN            NaN          NaN
# 26   Weights & Biases           NaN          NaN            NaN          NaN
# 27                 NaN          NaN          NaN            NaN          NaN
# 28                 NaN          NaN          NaN            NaN          NaN
# 29                 NaN          NaN          NaN            NaN          NaN
# 30                 NaN          NaN          NaN            NaN          NaN
#
#    Q35_B_Part_7 Q35_B_Part_8 Q35_B_Part_9 Q35_B_Part_10 Q35_B_OTHER
# 1           NaN          NaN          NaN           NaN         NaN
# 2           NaN          NaN          NaN           NaN         NaN
# 3           NaN          NaN          NaN          None         NaN
# 4           NaN          NaN          NaN           NaN         NaN
# 5           NaN          NaN          NaN           NaN         NaN
# 6           NaN          NaN          NaN           NaN         NaN
# 7           NaN          NaN          NaN           NaN         NaN
# 8           NaN          NaN          NaN           NaN         NaN
# 9           NaN          NaN          NaN           NaN         NaN
# 10          NaN          NaN          NaN           NaN         NaN
# 11          NaN          NaN          NaN           NaN         NaN
# 12          NaN          NaN          NaN           NaN         NaN
# 13          NaN          NaN          NaN          None         NaN
# 14          NaN          NaN          NaN           NaN         NaN
# 15          NaN          NaN          NaN          None         NaN
# 16          NaN          NaN          NaN          None         NaN
# 17          NaN          NaN          NaN           NaN         NaN
# 18    Polyaxon           NaN          NaN           NaN         NaN
# 19          NaN          NaN          NaN           NaN         NaN
# 20          NaN          NaN          NaN           NaN         NaN
# 21          NaN          NaN          NaN           NaN         NaN
# 22          NaN          NaN          NaN           NaN         NaN
# 23          NaN          NaN          NaN           NaN         NaN
# 24          NaN          NaN          NaN          None         NaN
# 25          NaN          NaN          NaN          None         NaN
# 26          NaN          NaN          NaN           NaN         NaN
# 27          NaN          NaN          NaN          None         NaN
# 28          NaN          NaN          NaN           NaN         NaN
# 29          NaN          NaN          NaN           NaN         NaN
# 30          NaN          NaN          NaN          None         NaN
#
# [30 rows x 355 columns]

# %% [markdown]
# ## 1. Responses Rate by Country
#
# The response rate for Indians is the highest about 29.2%(5,850 people). It is about 2.6 times higher than the second-ranked country, the USA.

# %%
full_pie = px.pie(full_data, full_data.columns[3],
                 title='Survey Responses Rate by Country',
                 template='seaborn', hole=0.5)
full_pie.update_traces(textposition='inside', textinfo='percent+label')
full_pie.update_layout(uniformtext_minsize=10, uniformtext_mode='hide')
full_pie.show()
# Out:
# <div>                            <div id="1268beb3-a439-49d7-8b37-c81977d82652" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1268beb3-a439-49d7-8b37-c81977d82652")) {                    Plotly.newPlot(                        "1268beb3-a439-49d7-8b37-c81977d82652",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.5, "hovertemplate": "Q3=%{label}<extra></extra>", "labels": ["Colombia", "USA", "Argentina", "USA", "Japan", "India", "Brazil", "China", "Germany", "China", "India", "USA", "Indonesia", "Canada", "Switzerland", "India", "Other", "Singapore", "India", "India", "India", "Russia", "Canada", "South Africa", "USA", "USA", "India", "Egypt", "Netherlands", "Russia", "Pakistan", "India", "Other", "India", "USA", "India", "Nepal", "Indonesia", "South Korea", "India", "USA", "Indonesia", "India", "Poland", "Belarus", "India", "India", "Other", "Tunisia", "Ukraine", "Belgium", "USA", "USA", "Germany", "Pakistan", "Saudi Arabia", "Taiwan", "Brazil", "USA", "India", "Indonesia", "Other", "Nigeria", "India", "Germany", "China", "China", "Italy", "India", "Taiwan", "USA", "Taiwan", "India", "Other", "Other", "Spain", "Singapore", "India", "Russia", "USA", "India", "Other", "Other", "United Arab Emirates", "India", "India", "Other", "Spain", "India", "Colombia", "India", "Mexico", "Canada", "India", "India", "India", "India", "India", "Other", "Nigeria", "Viet Nam", "Poland", "Thailand", "UK", "Other", "Egypt", "India", "USA", "France", "India", "Brazil", "Argentina", "Colombia", "Mexico", "Egypt", "USA", "Viet Nam", "India", "Other", "USA", "Ghana", "Russia", "Japan", "USA", "India", "Poland", "Ghana", "India", "Nigeria", "Ireland", "USA", "India", "Other", "Ghana", "Netherlands", "India", "Canada", "Nigeria", "India", "Other", "Philippines", "USA", "Nigeria", "France", "France", "China", "Netherlands", "Germany", "Morocco", "Spain", "India", "India", "Turkey", "Belgium", "Other", "Germany", "Egypt", "Saudi Arabia", "Russia", "India", "Other", "India", "Turkey", "Russia", "Italy", "USA", "USA", "Spain", "Spain", "India", "India", "India", "Iran, Islamic Republic of...", "Spain", "USA", "India", "UK", "USA", "India", "India", "Italy", "India", "USA", "Spain", "Germany", "India", "India", "USA", "India", "India", "India", "Japan", "Peru", "Other", "USA", "Egypt", "Germany", "Other", "Tunisia", "Romania", "India", "India", "India", "Russia", "USA", "India", "India", "India", "India", "India", "UK", "USA", "USA", "India", "USA", "India", "India", "India", "Nigeria", "Indonesia", "UK", "India", "Germany", "Taiwan", "Colombia", "India", "Nepal", "Italy", "Other", "USA", "India", "Japan", "USA", "Republic of Korea", "Russia", "UK", "India", "Australia", "USA", "Chile", "Japan", "Saudi Arabia", "India", "USA", "India", "USA", "USA", "India", "USA", "India", "India", "Canada", "India", "Japan", "India", "India", "India", "Other", "Brazil", "India", "USA", "Kenya", "Brazil", "India", "Italy", "India", "Spain", "USA", "Japan", "USA", "Russia", "Other", "Turkey", "India", "Germany", "India", "India", "USA", "India", "USA", "Turkey", "India", "Japan", "India", "India", "South Korea", "India", "Other", "India", "India", "Mexico", "China", "USA", "Ireland", "India", "India", "India", "Germany", "India", "Taiwan", "Iran, Islamic Republic of...", "Spain", "Sweden", "Spain", "Nigeria", "India", "Poland", "Germany", "Poland", "Tunisia", "Netherlands", "India", "Pakistan", "USA", "India", "Canada", "USA", "France", "India", "India", "Bangladesh", "India", "India", "India", "USA", "Kenya", "Other", "Japan", "India", "Brazil", "Turkey", "India", "India", "Other", "India", "Bangladesh", "Ghana", "China", "Greece", "Tunisia", "Other", "Other", "UK", "Indonesia", "Taiwan", "India", "Austra ...

# %% [markdown]
# I just use Americans and Indians responses for this report, so I extract data by only 2 countries.

# %%
data = full_data[(full_data['Q3']=='India')|(full_data['Q3']=='USA')]
data = data.iloc[1:,:]
data.reset_index(drop=True, inplace=True)
data.shape
# Out:
# (8087, 355)

# %% [markdown]
# To organize the data neatly, I preprocesse a gender column. Only female and male remain. (146 responses will be deleted)

# %%
data = data[(data['Q2']=='Man')|(data['Q2']=='Woman')]
data = data.iloc[1:,:]
data.reset_index(drop=True, inplace=True)
data.shape
# Out:
# (7941, 355)

# %%
print("- Valid American Response: ",len(data[data['Q3']=='USA']))
print("- Valid Indian Response: ",len(data[data['Q3']=='India']))
# Out:
# - Valid American Response:  2161
# - Valid Indian Response:  5780

# %% [markdown]
# Since difference of the number of respondents by 2 countries, I will compare all data with the response rate.

# %% [markdown]
# ## 2. Percentage by age & gender

# %%
India = data[data['Q3']=='India']
India = India.iloc[1:,:]
India.reset_index(drop=True, inplace=True)
India.head()
# Out:
#   Time from Start to Finish (seconds)     Q1     Q2     Q3                 Q4  \
# 0                                7469  18-21    Man  India  Bachelor’s degree
# 1                                 413  18-21  Woman  India  Bachelor’s degree
# 2                                 192  22-24    Man  India  Bachelor’s degree
# 3                                 267  18-21    Man  India  Bachelor’s degree
# 4                                3313  22-24  Woman  India    Doctoral degree
#
#              Q5         Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  ...  \
# 0       Student  1-2 years    Python         R       SQL  ...
# 1       Student  1-2 years       NaN         R       SQL  ...
# 2       Student  1-2 years    Python       NaN       SQL  ...
# 3       Student  1-2 years    Python       NaN       NaN  ...
# 4  Statistician  3-5 years       NaN         R       SQL  ...
#
#          Q35_B_Part_2 Q35_B_Part_3 Q35_B_Part_4 Q35_B_Part_5 Q35_B_Part_6  \
# 0                 NaN          NaN          NaN          NaN          NaN
# 1                 NaN          NaN          NaN          NaN          NaN
# 2                 NaN          NaN          NaN          NaN          NaN
# 3                 NaN          NaN          NaN          NaN          NaN
# 4   Weights & Biases           NaN          NaN          NaN          NaN
#
#   Q35_B_Part_7 Q35_B_Part_8 Q35_B_Part_9 Q35_B_Part_10 Q35_B_OTHER
# 0          NaN          NaN          NaN           NaN         NaN
# 1          NaN          NaN          NaN          None         NaN
# 2          NaN          NaN          NaN           NaN         NaN
# 3          NaN          NaN          NaN           NaN         NaN
# 4          NaN          NaN          NaN           NaN         NaN
#
# [5 rows x 355 columns]

# %%
USA = data[data['Q3']=='USA']
USA = USA.iloc[1:,:]
USA.reset_index(drop=True, inplace=True)
USA.head()
# Out:
#   Time from Start to Finish (seconds)     Q1     Q2   Q3                 Q4  \
# 0                                 571  50-54    Man  USA    Master’s degree
# 1                                 723  25-29  Woman  USA    Master’s degree
# 2                               65598  50-54  Woman  USA  Bachelor’s degree
# 3                                 340  30-34    Man  USA    Master’s degree
# 4                                5811  35-39    Man  USA    Master’s degree
#
#                   Q5                         Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  \
# 0  Software Engineer                  20+ years    Python       NaN       NaN
# 1            Student                  1-2 years    Python         R       NaN
# 2              Other  I have never written code       NaN       NaN       NaN
# 3            Student                  3-5 years    Python         R       SQL
# 4              Other                  < 1 years       NaN       NaN       NaN
#
#    ...        Q35_B_Part_2 Q35_B_Part_3 Q35_B_Part_4 Q35_B_Part_5  \
# 0  ...                 NaN          NaN          NaN          NaN
# 1  ...   Weights & Biases           NaN          NaN          NaN
# 2  ...                 NaN          NaN          NaN          NaN
# 3  ...                 NaN          NaN          NaN          NaN
# 4  ...                 NaN          NaN          NaN          NaN
#
#   Q35_B_Part_6 Q35_B_Part_7 Q35_B_Part_8 Q35_B_Part_9 Q35_B_Part_10  \
# 0          NaN          NaN          NaN          NaN          None
# 1          NaN          NaN          NaN          NaN           NaN
# 2          NaN          NaN          NaN          NaN           NaN
# 3          NaN          NaN          NaN          NaN          None
# 4          NaN          NaN          NaN          NaN           NaN
#
#   Q35_B_OTHER
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 355 columns]

# %%
f, ax = plt.subplots(1, 2, figsize = (12, 8))

USA['Q1'].value_counts().plot.pie(autopct='%.1f%%', ax = ax[0])
ax[0].set_title('Age Distribution in USA', fontsize=20)
ax[0].set_ylabel('')

India['Q1'].value_counts().plot.pie(autopct='%.1f%%', ax = ax[1])
ax[1].set_title('Age Distribution in India', fontsize=20)
ax[1].set_ylabel('')
plt.show()

# %% [markdown]
# Age|USA|India
# :---:|:---:|:---:
# 18-21|5.4%|35.3%
# 22-24|8.5%|26.0%
# 25-29|17.4%|18.0%
# 30-34|17.6%|9.1%
# 35-39|13.0%|5.3%
# 40-44|10.5%|3.0%
# 45-49|7.5%|1.8%
# 50-54|7.8%|0.8%
# 55-59|4.7%|0.6%
# 60-69|6.2%|0.2%
# 70+|1.4%|0.1%
#
# You can notice easily in the USA, distribution of age group is more regular than India. It represents the cording fever especially among young Indian.

# %%
q3_order = data['Q3'].value_counts()[:11].index
data_q2q3 = data[['Q2','Q3']].groupby('Q3')['Q2'].value_counts().unstack().loc[q3_order]
data_q2q3['sum'] = data_q2q3.sum(axis=1)
data_q2q3_ratio = (data_q2q3.T / data_q2q3['sum']).T[['Man','Woman']][::-1]

fig, ax = plt.subplots(1,1,figsize=(10, 2))

ax.barh(data_q2q3_ratio.index, data_q2q3_ratio['Man'], alpha=0.5, label='Man')
ax.barh(data_q2q3_ratio.index, data_q2q3_ratio['Woman'],
        left=data_q2q3_ratio['Man'], alpha=0.5, label='Woman')

ax.set_xlim(0, 1)
ax.set_xticks([])
ax.set_yticklabels(data_q2q3_ratio.index, fontsize=15)

# male percentage
for i in data_q2q3_ratio.index:
    ax.annotate(f"{data_q2q3_ratio['Man'][i]*100:.3}%", 
                   xy=(data_q2q3_ratio['Man'][i]/2, i), fontsize=12, va='center')

for i in data_q2q3_ratio.index:
    ax.annotate(f"{data_q2q3_ratio['Woman'][i]*100:.3}%", 
                   xy=(data_q2q3_ratio['Man'][i]+data_q2q3_ratio['Woman'][i]/2, i),
                   va='center', ha='center', fontsize=12)
    
plt.title('Gender Distribution', fontsize=20)   

for s in ['top', 'left', 'right', 'bottom']:
    ax.spines[s].set_visible(False)
    
ax.legend(loc='lower center', ncol=2, bbox_to_anchor=(0.5, -0.25))
plt.show()

# %% [markdown]
# The gender raions of two countires are alike.

# %% [markdown]
# ## 3. Level of Education

# %%
f, ax = plt.subplots(1, 2, figsize = (12, 8))

data[data.columns[4]].replace({'No formal education past high school':'~ High school',
                             'I prefer not to answer':'Not answer',
                             "Some college/university study without earning a bachelor's degree":"Study without a bachelor's degree",}, inplace=True)

USA = data.groupby('Q3').get_group('USA')
India = data.groupby('Q3').get_group('India')

USA[USA.columns[4]].value_counts().plot.pie(autopct='%.1f%%', ax = ax[0])
ax[0].set_title('Education Level in USA', fontsize=20)
ax[0].set_ylabel('')

India[India.columns[4]].value_counts().plot.pie(autopct='%.1f%%', ax = ax[1])
ax[1].set_title('Education Level in India', fontsize=20)
ax[1].set_ylabel('')
plt.show()

# %%
f, ax = plt.subplots(1, 2, figsize = (12, 8))

USA[USA.columns[4]].replace({

USA['Q6'].value_counts().plot.pie(autopct='%.1f%%', ax = ax[0])
ax[0].set_title('Period of Cording in USA', fontsize=20)
ax[0].set_ylabel('')

India['Q6'].value_counts().plot.pie(autopct='%.1f%%', ax = ax[1])
ax[1].set_title('Period of Cording in India', fontsize=20)
ax[1].set_ylabel('')
plt.show()

# %%
f, ax = plt.subplots(1, 2, figsize = (12, 8))

USA['count']=1
sns.heatmap(pd.pivot_table(USA, values='count', index=['Q6'], columns=['Q4'], aggfunc=np.sum), 
            cmap="YlGnBu",
            square=True, 
            linewidth=2, 
            cbar=False, 
            annot=True)
ax[0].set_title('Level of Education in USA', fontsize=20)
ax[0].set_ylabel('')

India['count']=1
sns.heatmap(pd.pivot_table(India, values='count', index=['Q6'], columns=['Q4'], aggfunc=np.sum), 
            cmap="YlGnBu",
            square=True, 
            linewidth=2, 
            cbar=False, 
            annot=True)
ax[1].set_title('Level of Education in India', fontsize=20)
ax[1].set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Development Environment

# %% [markdown]
# ## 5. Basic of Machine Learning

# %% [markdown]
# ## 6. CV vs NLP

# %% [markdown]
# ## 7. Machine Learning in the business
