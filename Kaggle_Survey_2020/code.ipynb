# %% [markdown]
# - 그래프 코드
#
# ![image.png](attachment:image.png)

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=1, cols=2, shared_yaxes=True, horizontal_spacing = 0)

degree=['I prefer not to answer',
        'No formal education<br>past high school',
        'Some college/university<br>study without earning<br>a bachelor’s degree',
        'Professional degree',
        'Bachelor’s degree',
        'Master’s degree',
        'Doctoral degree']

color_men = ['lightblue'] * 7
color_women = ['pink'] * 7
color_other = ['#FFDAC1'] * 7

fig.add_trace(go.Bar(name='Man', y=degree, x=[232, 92, 221,237, 906, 1862,731],orientation='h',marker_color=color_men),row=1, col=1)
fig.add_trace(go.Bar(name='Woman', y=degree, x=[46, 4, 29, 43, 164, 412, 171],orientation='h',marker_color=color_women),row=1, col=1)
fig.add_trace(go.Bar(name='Other', y=degree, x=[16, 4, 5, 2, 19, 37, 14],orientation='h', marker_color=color_other), row=1, col=1)

fig.add_trace(go.Bar(name='Man', y=degree, x=[78.9, 92.0, 86.7,84.0, 83.2, 80.6,79.8],orientation='h',marker_color=color_men, showlegend=False),row=1, col=2)
fig.add_trace(go.Bar(name='Woman', y=degree, x=[15.6, 4.0, 11.4, 15.2, 15.1, 17.8, 18.7],orientation='h',marker_color=color_women, showlegend=False),row=1, col=2)
fig.add_trace(go.Bar(name='Other', y=degree, x=[5.5, 4.0, 1.9, 0.8, 1.7, 1.6, 1.5],orientation='h', marker_color=color_other, showlegend=False), row=1, col=2)

fig.update_layout({'plot_bgcolor': 'rgba(0, 0, 0, 0)',
                  'paper_bgcolor': 'rgba(0, 0, 0, 0)'},
                  barmode='stack',
                  title='Kagglers that Started Coding at 30+ Years Old,<br>Highest Level of Formal Education wrt Gender' \
          '<br><span style="font-size:10px"><i>What\'s Your Highest Degree Pedro?</span></i>')

# edit axis labels
fig['layout']['xaxis']['title']='Count'
fig['layout']['xaxis2']['title']='%'

fig.show()

# %% [markdown]
# 1. 조건에 맞는 행 추출

# %%
India = full_data[full_data['Q3']=='India']
India = India.iloc[1:,:]
India.reset_index(drop=True, inplace=True)
India.head()

# %%
USA = full_data[full_data['Q3']=='USA']
USA = USA.iloc[1:,:]
USA.reset_index(drop=True, inplace=True)
USA.head()

# %%
data = full_data[(full_data['Q3']=='India')|(full_data['Q3']=='USA')]
data = data.iloc[1:,:]
data.reset_index(drop=True, inplace=True)
data.head()
# Out:
#   Time from Start to Finish (seconds)     Q1     Q2     Q3                 Q4  \
# 0                                 507  30-34    Man    USA    Master’s degree
# 1                                 401  30-34    Man  India  Bachelor’s degree
# 2                                7469  18-21    Man  India  Bachelor’s degree
# 3                                 742  35-39    Man    USA    Doctoral degree
# 4                                 413  18-21  Woman  India  Bachelor’s degree
#
#                    Q5          Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  ...  \
# 0      Data Scientist  5-10 years    Python       NaN       SQL  ...
# 1        Data Analyst   < 1 years    Python         R       NaN  ...
# 2             Student   1-2 years    Python         R       SQL  ...
# 3  Research Scientist   1-2 years       NaN         R       NaN  ...
# 4             Student   1-2 years       NaN         R       SQL  ...
#
#   Q35_B_Part_2 Q35_B_Part_3 Q35_B_Part_4 Q35_B_Part_5 Q35_B_Part_6  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Q35_B_Part_7 Q35_B_Part_8 Q35_B_Part_9 Q35_B_Part_10 Q35_B_OTHER
# 0          NaN          NaN          NaN           NaN         NaN
# 1          NaN          NaN          NaN           NaN         NaN
# 2          NaN          NaN          NaN           NaN         NaN
# 3          NaN          NaN          NaN           NaN         NaN
# 4          NaN          NaN          NaN          None         NaN
#
# [5 rows x 355 columns]

# %%
import pandas as pd

# 최대 줄 수 설정
pd.set_option('display.max_rows', 500)
# 최대 열 수 설정
pd.set_option('display.max_columns', 500)
# 표시할 가로의 길이
pd.set_option('display.width', 1000)

pd.describe_option() #해당 DataFrame의 옵션을 모두 볼 수 있다.

# %% [markdown]
# 인도 미국 연령대 비교

# %%
age_USA = px.pie(USA, USA.columns[1],
                 title='Age Distribution in USA',
                 template='seaborn',)
age_USA.update_traces(textposition='inside', textinfo='percent+label')
age_USA.update_layout(uniformtext_minsize=10)
age_USA.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ca564f4b0cdc> in <module>
# ----> 1 age_USA = px.pie(USA, USA.columns[1],
#       2                  title='Age Distribution in USA',
#       3                  template='seaborn',)
#       4 age_USA.update_traces(textposition='inside', textinfo='percent+label')
#       5 age_USA.update_layout(uniformtext_minsize=10)
#
# NameError: name 'px' is not defined

# %%
age_India = px.pie(India, India.columns[1],
                 title='Age Distribution in India',
                 template='seaborn')
age_India.update_traces(textposition='inside', textinfo='percent+label')
age_India.update_layout(uniformtext_minsize=10)
age_India.show()

# %%
USA|  |   |India|  |
---|---|---|---|---
18-21|5.4%|  |18-21|35.3%
22-24|8.5%|  |22-24|26.0%
25-29|17.4%|  |25-29|18.0%
30-34|17.6%|  |30-34|9.1%
35-39|13.0%|  |35-39|5.3%
40-44|10.5%|  |40-44|3.0%
45-49|7.5%|  |45-49|1.8%
50-54|7.8%|  |50-54|0.8%
55-59|4.7%|  |55-59|0.6%
60-69|6.2%|  |60-69|0.2%
70+|1.4%|  |70+|0.1%
